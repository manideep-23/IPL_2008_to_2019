# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # The total records in the dataset

# %%
ipl_del=pd.read_csv('deliveries.csv');
ipl_match=pd.read_csv('matches.csv');
ipl_match.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
ipl_del.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...         0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...         0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...         0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...         0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %%
ipl_match.describe()
# Out:
#                  id       season  dl_applied  win_by_runs  win_by_wickets
# count    756.000000   756.000000  756.000000   756.000000      756.000000
# mean    1792.178571  2013.444444    0.025132    13.283069        3.350529
# std     3464.478148     3.366895    0.156630    23.471144        3.387963
# min        1.000000  2008.000000    0.000000     0.000000        0.000000
# 25%      189.750000  2011.000000    0.000000     0.000000        0.000000
# 50%      378.500000  2013.000000    0.000000     0.000000        4.000000
# 75%      567.250000  2016.000000    0.000000    19.000000        6.000000
# max    11415.000000  2019.000000    1.000000   146.000000       10.000000

# %%
ipl_match.count()
# Out:
# id                 756
# season             756
# city               749
# date               756
# team1              756
# team2              756
# toss_winner        756
# toss_decision      756
# result             756
# dl_applied         756
# winner             752
# win_by_runs        756
# win_by_wickets     756
# player_of_match    752
# venue              756
# umpire1            754
# umpire2            754
# umpire3            119
# dtype: int64

# %% [markdown]
# # Total number of matches played:

# %%
print("Number of matches played so far : ", ipl_match.shape[0])
# Out:
# Number of matches played so far :  756

# %%
ipl_match.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 756 entries, 0 to 755
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               756 non-null    int64
#  1   season           756 non-null    int64
#  2   city             749 non-null    object
#  3   date             756 non-null    object
#  4   team1            756 non-null    object
#  5   team2            756 non-null    object
#  6   toss_winner      756 non-null    object
#  7   toss_decision    756 non-null    object
#  8   result           756 non-null    object
#  9   dl_applied       756 non-null    int64
#  10  winner           752 non-null    object
#  11  win_by_runs      756 non-null    int64
#  12  win_by_wickets   756 non-null    int64
#  13  player_of_match  752 non-null    object
#  14  venue            756 non-null    object
#  15  umpire1          754 non-null    object
#  16  umpire2          754 non-null    object
# ...

# %% [markdown]
# # Number of Seasons Played:

# %%
print("Number of seasons played: ", ipl_match['season'].nunique())
# Out:
# Number of seasons played:  12

# %% [markdown]
# # Most player  of the match :

# %%
ipl_match['player_of_match']
# Out:
# 0      Yuvraj Singh
# 1         SPD Smith
# 2           CA Lynn
# 3        GJ Maxwell
# 4         KM Jadhav
#            ...
# 751       HH Pandya
# 752        AS Yadav
# 753         RR Pant
# 754    F du Plessis
# 755       JJ Bumrah
# Name: player_of_match, Length: 756, dtype: object

# %%
ipl_match['player_of_match'].value_counts()[:10]
# Out:
# CH Gayle          21
# AB de Villiers    20
# MS Dhoni          17
# RG Sharma         17
# DA Warner         17
# YK Pathan         16
# SR Watson         15
# SK Raina          14
# G Gambhir         13
# V Kohli           12
# Name: player_of_match, dtype: int64

# %% [markdown]
# # The player with most man of the match awards:

# %%
print((ipl_match['player_of_match'].value_counts()).idxmax(),' : has most man of the match awards with :',ipl_match['player_of_match'].value_counts().max())
# Out:
# CH Gayle  : has most man of the match awards with : 21

# %% [markdown]
# # count total different  umpires

# %%
ipl_match['umpire1'].nunique()
# Out:
# 61

# %%
ipl_match['umpire2'].nunique()
# Out:
# 65

# %%
ipl_match['umpire3'].nunique()
# Out:
# 25

# %% [markdown]
# # The team with more number of wins:

# %%
print(((ipl_match['winner']).value_counts()).idxmax(),': has the highest number of match wins with ',ipl_match['winner'].value_counts().max()," wins")
# Out:
# Mumbai Indians : has the highest number of match wins with  109  wins

# %%
ipl_match['winner'].value_counts()
# Out:
# Mumbai Indians                 109
# Chennai Super Kings            100
# Kolkata Knight Riders           92
# Royal Challengers Bangalore     84
# Kings XI Punjab                 82
# Rajasthan Royals                75
# Delhi Daredevils                67
# Sunrisers Hyderabad             58
# Deccan Chargers                 29
# Gujarat Lions                   13
# Pune Warriors                   12
# Rising Pune Supergiant          10
# Delhi Capitals                  10
# Kochi Tuskers Kerala             6
# Rising Pune Supergiants          5
# Name: winner, dtype: int64

# %% [markdown]
# # or You can use groupBy to get the result

# %%
team=ipl_match.groupby(['winner'],as_index=False).count()
#print(team['winner']," :",team['result'])
print(team[['winner','result']])
# Out:
#                          winner  result
# 0           Chennai Super Kings     100
# 1               Deccan Chargers      29
# 2                Delhi Capitals      10
# 3              Delhi Daredevils      67
# 4                 Gujarat Lions      13
# 5               Kings XI Punjab      82
# 6          Kochi Tuskers Kerala       6
# 7         Kolkata Knight Riders      92
# 8                Mumbai Indians     109
# 9                 Pune Warriors      12
# 10             Rajasthan Royals      75
# 11       Rising Pune Supergiant      10
# 12      Rising Pune Supergiants       5
# 13  Royal Challengers Bangalore      84
# 14          Sunrisers Hyderabad      58

# %%
team['result'].max()
# Out:
# 109

# %%
team['result']==(team['result'].max())
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8      True
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# Name: result, dtype: bool

# %%
team.head().sort_values(['winner'],ascending=True)
# Out:
#                 winner   id  season  city  date  team1  team2  toss_winner  \
# 0  Chennai Super Kings  100     100    98   100    100    100          100
# 1      Deccan Chargers   29      29    29    29     29     29           29
# 2       Delhi Capitals   10      10    10    10     10     10           10
# 3     Delhi Daredevils   67      67    66    67     67     67           67
# 4        Gujarat Lions   13      13    13    13     13     13           13
#
#    toss_decision  result  dl_applied  win_by_runs  win_by_wickets  \
# 0            100     100         100          100             100
# 1             29      29          29           29              29
# 2             10      10          10           10              10
# 3             67      67          67           67              67
# 4             13      13          13           13              13
#
#    player_of_match  venue  umpire1  umpire2  umpire3
# 0              100    100      100      100       21
# ...

# %%
print(team[team['result']==(team['result'].max())]['winner'],":",team[team['result']==(team['result'].max())]['result'])
# Out:
# 8    Mumbai Indians
# Name: winner, dtype: object : 8    109
# Name: result, dtype: int64

# %% [markdown]
# # The teams which won by a margin greater than 100 runs :

# %%
match_with_margin=ipl_match[ipl_match['win_by_runs']>=100]

# %%
match_with_margin[['season','team1','team2','winner','win_by_runs']]
# Out:
#      season                        team1                        team2  \
# 43     2017               Mumbai Indians             Delhi Daredevils
# 59     2008        Kolkata Knight Riders  Royal Challengers Bangalore
# 114    2008             Rajasthan Royals             Delhi Daredevils
# 295    2011              Kings XI Punjab  Royal Challengers Bangalore
# 410    2013  Royal Challengers Bangalore                Pune Warriors
# 556    2015  Royal Challengers Bangalore              Kings XI Punjab
# 619    2016  Royal Challengers Bangalore                Gujarat Lions
# 676    2018               Mumbai Indians        Kolkata Knight Riders
# 706    2019          Sunrisers Hyderabad  Royal Challengers Bangalore
#
#                           winner  win_by_runs
# 43                Mumbai Indians          146
# 59         Kolkata Knight Riders          140
# 114             Rajasthan Royals          105
# 295              Kings XI Punjab          111
# ...

# %%
match_with_margin['winner']
# Out:
# 43                  Mumbai Indians
# 59           Kolkata Knight Riders
# 114               Rajasthan Royals
# 295                Kings XI Punjab
# 410    Royal Challengers Bangalore
# 556    Royal Challengers Bangalore
# 619    Royal Challengers Bangalore
# 676                 Mumbai Indians
# 706            Sunrisers Hyderabad
# Name: winner, dtype: object

# %%
match_with_margin['winner'].value_counts()
# Out:
# Royal Challengers Bangalore    3
# Mumbai Indians                 2
# Rajasthan Royals               1
# Sunrisers Hyderabad            1
# Kings XI Punjab                1
# Kolkata Knight Riders          1
# Name: winner, dtype: int64

# %% [markdown]
# # The teams which won by  8 wickets while chasing  :

# %%
match_with_margin2=ipl_match[ipl_match['win_by_wickets']>=8]

# %%
match_with_margin2[['season','team1','team2','winner','win_by_wickets']]
# Out:
#      season                        team1                        team2  \
# 2      2017                Gujarat Lions        Kolkata Knight Riders
# 5      2017                Gujarat Lions          Sunrisers Hyderabad
# 7      2017  Royal Challengers Bangalore              Kings XI Punjab
# 10     2017              Kings XI Punjab        Kolkata Knight Riders
# 21     2017              Kings XI Punjab               Mumbai Indians
# ..      ...                          ...                          ...
# 704    2019               Mumbai Indians              Kings XI Punjab
# 716    2019             Rajasthan Royals        Kolkata Knight Riders
# 723    2019              Kings XI Punjab  Royal Challengers Bangalore
# 733    2019        Kolkata Knight Riders          Sunrisers Hyderabad
# 751    2019        Kolkata Knight Riders               Mumbai Indians
#
#                           winner  win_by_wickets
# 2          Kolkata Knight Riders              10
# ...

# %%
match_with_margin2['winner'].value_counts()
# Out:
# Royal Challengers Bangalore    16
# Kolkata Knight Riders          16
# Delhi Daredevils               13
# Mumbai Indians                 13
# Chennai Super Kings            11
# Rajasthan Royals               11
# Sunrisers Hyderabad             8
# Kings XI Punjab                 8
# Kochi Tuskers Kerala            2
# Deccan Chargers                 2
# Rising Pune Supergiants         1
# Rising Pune Supergiant          1
# Name: winner, dtype: int64

# %%
ipl_match['umpire3'].unique()
# Out:
# array([nan, 'Anil Chaudhary', 'Nitin Menon', 'S Ravi', 'O Nandan',
#        'A Nanda Kishore', 'Vineet Kulkarni', 'C Shamshuddin',
#        'Rod Tucker', 'Chris Gaffaney', 'A.D Deshmukh', 'Nigel Llong',
#        'K Ananthapadmanabhan', 'Anil Dandekar', 'Virender Kumar Sharma',
#        'Yeshwant Barde', 'Bruce Oxenford', 'Marais Erasmus',
#        'Kumar Dharmasena', 'KN Anantapadmanabhan', 'Ulhas Gandhe',
#        'Nanda Kishore', 'Ian Gould', 'Sundaram Ravi',
#        'KN Ananthapadmanabhan', 'Chettithody Shamshuddin'], dtype=object)

# %%
ipl_match.iloc[[ipl_match['win_by_runs'].idxmax()]]
# Out:
#     id  season   city        date           team1             team2  \
# 43  44    2017  Delhi  2017-05-06  Mumbai Indians  Delhi Daredevils
#
#          toss_winner toss_decision  result  dl_applied          winner  \
# 43  Delhi Daredevils         field  normal           0  Mumbai Indians
#
#     win_by_runs  win_by_wickets player_of_match             venue  \
# 43          146               0     LMP Simmons  Feroz Shah Kotla
#
#         umpire1    umpire2 umpire3
# 43  Nitin Menon  CK Nandan     NaN

# %%
ipl_match.iloc[[ipl_match['win_by_wickets'].idxmax()]]
# Out:
#    id  season    city        date          team1                  team2  \
# 2   3    2017  Rajkot  2017-04-07  Gujarat Lions  Kolkata Knight Riders
#
#              toss_winner toss_decision  result  dl_applied  \
# 2  Kolkata Knight Riders         field  normal           0
#
#                   winner  win_by_runs  win_by_wickets player_of_match  \
# 2  Kolkata Knight Riders            0              10         CA Lynn
#
#                                     venue      umpire1    umpire2 umpire3
# 2  Saurashtra Cricket Association Stadium  Nitin Menon  CK Nandan     NaN

# %%
ipl_del.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 179078 entries, 0 to 179077
# Data columns (total 21 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   match_id          179078 non-null  int64
#  1   inning            179078 non-null  int64
#  2   batting_team      179078 non-null  object
#  3   bowling_team      179078 non-null  object
#  4   over              179078 non-null  int64
#  5   ball              179078 non-null  int64
#  6   batsman           179078 non-null  object
#  7   non_striker       179078 non-null  object
#  8   bowler            179078 non-null  object
#  9   is_super_over     179078 non-null  int64
#  10  wide_runs         179078 non-null  int64
#  11  bye_runs          179078 non-null  int64
#  12  legbye_runs       179078 non-null  int64
#  13  noball_runs       179078 non-null  int64
#  14  penalty_runs      179078 non-null  int64
#  15  batsman_runs      179078 non-null  int64
# ...

# %%
ipl_del
# Out:
#         match_id  inning         batting_team                 bowling_team  \
# 0              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 1              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 2              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 3              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 4              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# ...          ...     ...                  ...                          ...
# 179073     11415       2  Chennai Super Kings               Mumbai Indians
# 179074     11415       2  Chennai Super Kings               Mumbai Indians
# 179075     11415       2  Chennai Super Kings               Mumbai Indians
# 179076     11415       2  Chennai Super Kings               Mumbai Indians
# 179077     11415       2  Chennai Super Kings               Mumbai Indians
#
# ...

# %%
import seaborn as sns
data=pd.read_csv('matches.csv')

# %%
sns.set(style='darkgrid')
fig=plt.gcf()
fig.set_size_inches(18.5,10.5)
wins=pd.DataFrame(data['winner'].value_counts())
wins['name']=wins.index

print(wins)
# Out:
#                              winner                         name
# Mumbai Indians                  109               Mumbai Indians
# Chennai Super Kings             100          Chennai Super Kings
# Kolkata Knight Riders            92        Kolkata Knight Riders
# Royal Challengers Bangalore      84  Royal Challengers Bangalore
# Kings XI Punjab                  82              Kings XI Punjab
# Rajasthan Royals                 75             Rajasthan Royals
# Delhi Daredevils                 67             Delhi Daredevils
# Sunrisers Hyderabad              58          Sunrisers Hyderabad
# Deccan Chargers                  29              Deccan Chargers
# Gujarat Lions                    13                Gujarat Lions
# Pune Warriors                    12                Pune Warriors
# Rising Pune Supergiant           10       Rising Pune Supergiant
# Delhi Capitals                   10               Delhi Capitals
# ...

# %%
sns.set(style='darkgrid')
fig=plt.gcf()
fig.set_size_inches(18.5,10.5)
wins=pd.DataFrame(data['winner'].value_counts())
wins['name']=wins.index

plt.xticks(rotation=90,fontsize=12)
plt.yticks(fontsize=16)
plt.bar(wins['name'],
        wins['winner'],
        color=['#15244C','#FFFF48','#292734','#EF2920','#CD202D','#ECC5F2',
               '#294A73','#D4480B','#242307','#FD511F','#158EA6','#E82865',
               '#005DB7','#C23E25','#E82865']
        ,alpha=0.8)
count=0
for i in wins['winner']:
    plt.text(count-0.15,i-4,str(i),size=15,color='black',rotation=90)
    count+=1
plt.title('Total wins by each team',fontsize=20)
plt.xlabel('Teams',fontsize=15)
plt.ylabel('Total no. of matches won(2008-2019)',fontsize=14)
plt.show()

# %% [markdown]
# # MI VS CSK STATS:

# %%
 mi_vs_csk=data[np.logical_or(np.logical_and(data['team1']=='Mumbai Indians',data['team2']=='Chennai Super Kings'),np.logical_and(data['team2']=='Mumbai Indians',data['team1']=='Chennai Super Kings'))]

# %%
mi_vs_csk[['season','date','team1','team2','winner','player_of_match']]
# Out:
#      season        date                team1                team2  \
# 66     2008  2008-04-23  Chennai Super Kings       Mumbai Indians
# 95     2008  2008-05-14  Chennai Super Kings       Mumbai Indians
# 117    2009  2009-04-18       Mumbai Indians  Chennai Super Kings
# 161    2009  2009-05-16       Mumbai Indians  Chennai Super Kings
# 193    2010  2010-03-25  Chennai Super Kings       Mumbai Indians
# 210    2010  2010-04-06  Chennai Super Kings       Mumbai Indians
# 233    2010  2010-04-25  Chennai Super Kings       Mumbai Indians
# 256    2011  2011-04-22       Mumbai Indians  Chennai Super Kings
# 307    2012  2012-04-04  Chennai Super Kings       Mumbai Indians
# 354    2012  2012-05-06  Chennai Super Kings       Mumbai Indians
# 378    2012  2012-05-23  Chennai Super Kings       Mumbai Indians
# 385    2013  2013-04-06       Mumbai Indians  Chennai Super Kings
# 429    2013  2013-05-05       Mumbai Indians  Chennai Super Kings
# ...

# %%
mi_vs_csk.count()
# Out:
# id                 28
# season             28
# city               27
# date               28
# team1              28
# team2              28
# toss_winner        28
# toss_decision      28
# result             28
# dl_applied         28
# winner             28
# win_by_runs        28
# win_by_wickets     28
# player_of_match    28
# venue              28
# umpire1            28
# umpire2            28
# umpire3             6
# dtype: int64

# %%
mi_vs_csk['winner'].value_counts()
# Out:
# Mumbai Indians         17
# Chennai Super Kings    11
# Name: winner, dtype: int64

# %%
mi_vs_csk['winner'].value_counts()['Mumbai Indians']
# Out:
# 17

# %%
mi_vs_csk['winner'].value_counts()['Chennai Super Kings']
# Out:
# 11

# %%
sns.set(style='dark')
fig=plt.gcf()
fig.set_size_inches(10,8)
sns.countplot(mi_vs_csk['winner'],order=mi_vs_csk['winner'].value_counts().index)
plt.text(-0.1,15,str(mi_vs_csk['winner'].value_counts()['Mumbai Indians']),size=29,color='white')
plt.text(0.9,9,str(mi_vs_csk['winner'].value_counts()['Chennai Super Kings']),size=29,color='white')
plt.xlabel('Winner',fontsize=15)
plt.ylabel('Count',fontsize=15)
plt.yticks(fontsize=0)
plt.title('MI vs CSK - head to head')
plt.show()

# %% [markdown]
# # MI vs CSK - Best performers

# %%
sns.set(style='darkgrid')
fig=plt.gcf()
fig.set_size_inches(18.5,8)
sns.countplot(mi_vs_csk['player_of_match'],order=mi_vs_csk['player_of_match'].value_counts().index,palette='Set2')
plt.title('All man of the match awards in MI-CSK games',fontsize=15)
plt.yticks([1,2,3],[1,2,3],fontsize=15)
plt.xticks(fontsize=15,rotation=90)
plt.xlabel('Man of the match',fontsize=15)
plt.ylabel('Count',fontsize=15)
plt.show()

# %% [markdown]
# # Toss decision statistics for all MIvCSK matches - Venue wise

# %%
sns.set(style='darkgrid')
fig=plt.gcf()
fig.set_size_inches(18.5,8)
sns.countplot(mi_vs_csk['venue'],order=mi_vs_csk['venue'].value_counts().index,palette='Set2',hue=data['toss_decision'])
plt.title('Toss decision at each venue in MIvCSK matches',fontsize=15)
plt.yticks(fontsize=15)
plt.xticks(fontsize=15,rotation=90)
plt.xlabel('Venue',fontsize=15)
plt.ylabel('Count',fontsize=15)
plt.legend(loc=5,fontsize=15)
plt.show()

# %% [markdown]
# # Which team won most matches while chasing?¶

# %%
ipl_match
# Out:
#         id  season           city        date                        team1  \
# 0        1    2017      Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1        2    2017           Pune  2017-04-06               Mumbai Indians
# 2        3    2017         Rajkot  2017-04-07                Gujarat Lions
# 3        4    2017         Indore  2017-04-08       Rising Pune Supergiant
# 4        5    2017      Bangalore  2017-04-08  Royal Challengers Bangalore
# ..     ...     ...            ...         ...                          ...
# 751  11347    2019         Mumbai    05/05/19        Kolkata Knight Riders
# 752  11412    2019        Chennai    07/05/19          Chennai Super Kings
# 753  11413    2019  Visakhapatnam    08/05/19          Sunrisers Hyderabad
# 754  11414    2019  Visakhapatnam    10/05/19               Delhi Capitals
# 755  11415    2019      Hyderabad    12/05/19               Mumbai Indians
#
# ...

# %%
#chasing=ipl_match[ipl_match['toss_decision']=='field' ]
chase=ipl_match[np.logical_and(ipl_match['winner'],ipl_match['win_by_wickets']>0)]
chase[['winner','win_by_wickets']]
#chasing
# Out:
#                      winner  win_by_wickets
# 1    Rising Pune Supergiant               7
# 2     Kolkata Knight Riders              10
# 3           Kings XI Punjab               6
# 5       Sunrisers Hyderabad               9
# 6            Mumbai Indians               4
# ..                      ...             ...
# 750         Kings XI Punjab               6
# 751          Mumbai Indians               9
# 752          Mumbai Indians               6
# 753          Delhi Capitals               2
# 754     Chennai Super Kings               6
#
# [406 rows x 2 columns]

# %%
chase['winner'].value_counts()
# Out:
# Kolkata Knight Riders          56
# Mumbai Indians                 50
# Chennai Super Kings            48
# Royal Challengers Bangalore    48
# Rajasthan Royals               46
# Kings XI Punjab                42
# Delhi Daredevils               42
# Sunrisers Hyderabad            27
# Gujarat Lions                  12
# Deccan Chargers                11
# Delhi Capitals                  6
# Pune Warriors                   6
# Rising Pune Supergiant          5
# Kochi Tuskers Kerala            4
# Rising Pune Supergiants         3
# Name: winner, dtype: int64

# %%
sns.set(style='darkgrid')
fig=plt.gcf()
fig.set_size_inches(18.5,10.5)
wins=pd.DataFrame(chase['winner'].value_counts())
wins['name']=wins.index

plt.xticks(rotation=90,fontsize=12)
plt.yticks(fontsize=16)
plt.bar(wins['name'],
        wins['winner'],
        color=['#15244C','#FFFF48','#292734','#EF2920','#CD202D','#ECC5F2',
               '#294A73','#D4480B','#242307','#FD511F','#158EA6','#E82865',
               '#005DB7','#C23E25','#E82865']
        ,alpha=0.8)
count=0
for i in wins['winner']:
    plt.text(count-0.15,i-4,str(i),size=15,color='black',rotation=90)
    count+=1
plt.title('Total wins by each team while chasing',fontsize=20)
plt.xlabel('Teams',fontsize=15)
plt.ylabel('Total no. of matches won while chasing(2008-2019)',fontsize=14)
plt.show()

# %% [markdown]
# # Which team won most matches when batting first?¶

# %%
defend=ipl_match[np.logical_and(ipl_match['winner'],ipl_match['win_by_runs']>0)]
defend[['winner','win_by_runs']]
# Out:
#                           winner  win_by_runs
# 0            Sunrisers Hyderabad           35
# 4    Royal Challengers Bangalore           15
# 8               Delhi Daredevils           97
# 13         Kolkata Knight Riders           17
# 14              Delhi Daredevils           51
# ..                           ...          ...
# 741               Delhi Capitals           16
# 742        Kolkata Knight Riders           34
# 743          Sunrisers Hyderabad           45
# 745          Chennai Super Kings           80
# 755               Mumbai Indians            1
#
# [337 rows x 2 columns]

# %%
defend['winner'].value_counts()
# Out:
# Mumbai Indians                 57
# Chennai Super Kings            52
# Kings XI Punjab                38
# Kolkata Knight Riders          36
# Royal Challengers Bangalore    35
# Sunrisers Hyderabad            30
# Rajasthan Royals               27
# Delhi Daredevils               25
# Deccan Chargers                18
# Pune Warriors                   6
# Rising Pune Supergiant          5
# Delhi Capitals                  3
# Rising Pune Supergiants         2
# Kochi Tuskers Kerala            2
# Gujarat Lions                   1
# Name: winner, dtype: int64

# %%
sns.set(style='darkgrid')
fig=plt.gcf()
fig.set_size_inches(18.5,10.5)
wins=pd.DataFrame(defend['winner'].value_counts())
wins['name']=wins.index

plt.xticks(rotation=90,fontsize=12)
plt.yticks(fontsize=16)
plt.bar(wins['name'],
        wins['winner'],
        color=['#15244C','#FFFF48','#292734','#EF2920','#CD202D','#ECC5F2',
               '#294A73','#D4480B','#242307','#FD511F','#158EA6','#E82865',
               '#005DB7','#C23E25','#E82865']
        ,alpha=0.8)
count=0
for i in wins['winner']:
    plt.text(count-0.15,i-4,str(i),size=15,color='black',rotation=90)
    count+=1
plt.title('Total wins by each team while defending',fontsize=20)
plt.xlabel('Teams',fontsize=15)
plt.ylabel('Total no. of matches won while defending(2008-2019)',fontsize=14)
plt.show()

# %%
season_now=ipl_match[np.logical_and(ipl_match['season']==2019,ipl_match['winner']=='Mumbai Indians')]
df1=pd.read_csv('matches.csv')
csk='Chennai Super Kings'
mi='Mumbai Indians'
kkr ='Kolkata Knight Riders'
rcb='Royal Challengers Bangalore'

# %%
csk_involved = (df1['team1'] == csk) | (df1['team2'] == csk)
mi_involved = (df1['team1'] == mi) | (df1['team2'] == mi)
kkr_involved = (df1['team1'] == kkr) | (df1['team2'] == kkr)
rcb_involved = (df1['team1'] == rcb) | (df1['team2'] == rcb)

mi_vs_csk_vc = df1[csk_involved & mi_involved]['winner'].value_counts()
mi_vs_kkr_vc = df1[kkr_involved & mi_involved]['winner'].value_counts()
mi_vs_rcb_vc = df1[rcb_involved & mi_involved]['winner'].value_counts()
csk_vs_kkr_vc = df1[csk_involved & kkr_involved]['winner'].value_counts()
csk_vs_rcb_vc = df1[csk_involved & rcb_involved]['winner'].value_counts()
kkr_vs_rcb_vc = df1[rcb_involved & kkr_involved]['winner'].value_counts()

fig, ax = plt.subplots(nrows = 1, ncols = 6, figsize=(20,8), sharey=True)

ax[0].set_ylabel('Matches Won')
ax[0].set_yticks(range(0, 30, 1))

def new_subplot(df = None, width = 0.3, title = "", ax = None, color = "SkyBlue", kind = 'bar', grid = True):
    df.plot(title = title, width = width, ax = ax, color = color, kind = kind, grid = grid)

new_subplot(mi_vs_csk_vc, title="MI vs CSK", ax = ax[0])
new_subplot(mi_vs_kkr_vc, title="MI vs KKR", ax = ax[1])
new_subplot(mi_vs_rcb_vc, title="MI vs RCB", ax = ax[2])
new_subplot(csk_vs_kkr_vc, title="CSK vs KKR", ax = ax[3])
new_subplot(csk_vs_rcb_vc, title="CSK vs RCB", ax = ax[4])
new_subplot(kkr_vs_rcb_vc, title="KKR vs RCB", ax = ax[5])

fig.tight_layout()

# %%
ipl_match2=(ipl_match['team1']=='Mumbai Indians')|(ipl_match['team2']=='Mumbai Indians')
ipl_match2
# Out:
# 0      False
# 1       True
# 2      False
# 3      False
# 4      False
#        ...
# 751     True
# 752     True
# 753    False
# 754    False
# 755     True
# Length: 756, dtype: bool

# %%
season_mi=ipl_match[np.logical_or(ipl_match['team1']=='Mumbai Indians',ipl_match['team2']=='Mumbai Indians')]
season_mi.date.count()

season_all
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-94-e058fc7aab01> in <module>
#       2 season_mi.date.count()
#       3
# ----> 4 season_all
#
# NameError: name 'season_all' is not defined

# %%
ipl_teams = pd.DataFrame(ipl_match['team1'])
#ipl_teams.set_index('team1')
#ipl_teams.team1.unique

# %% [markdown]
# # Total matches played by each team in ipl

# %%
ip=['Sunrisers Hyderabad','Royal Challengers Bangalore','Mumbai Indians',
 'Rising Pune Supergiant','Gujarat Lions','Kolkata Knight Riders',
 'Kings XI Punjab','Delhi Daredevils','Chennai Super Kings',
 'Rajasthan Royals','Deccan Chargers','Kochi Tuskers Kerala',
 'Pune Warriors','Rising Pune Supergiants','Delhi Capitals']
ipl_t=pd.DataFrame({"team1":ip
                 }) 

def fun(x):
    season_mi=ipl_match[np.logical_or(ipl_match['team1']==x,ipl_match['team2']==x)]
    return season_mi.date.count()

ipl_t['count']=ipl_t['team1'].apply(fun )
ipl_t.sort_values(by=['count'],ascending=False)
# Out:
#                           team1  count
# 2                Mumbai Indians    187
# 1   Royal Challengers Bangalore    180
# 5         Kolkata Knight Riders    178
# 6               Kings XI Punjab    176
# 8           Chennai Super Kings    164
# 7              Delhi Daredevils    161
# 9              Rajasthan Royals    147
# 0           Sunrisers Hyderabad    108
# 10              Deccan Chargers     75
# 12                Pune Warriors     46
# 4                 Gujarat Lions     30
# 3        Rising Pune Supergiant     16
# 14               Delhi Capitals     16
# 11         Kochi Tuskers Kerala     14
# 13      Rising Pune Supergiants     14
